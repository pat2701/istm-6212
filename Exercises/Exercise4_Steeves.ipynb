# %% [markdown]
# # Exercise 04 - Due Friday, October 21 at 12pm
#
# *Objectives*: Gain experience loading a CSV dataset into a database model you define yourself and using SQL to explore its contents. Explore the data by writing and executing a number of SQL queries using common syntax and functions and describing your findings.
#
# *Grading criteria*: The tasks should all be completed, and questions should all be answered with SQL queries in the space provided, unless a text answer is requested. Results should be correct, according to the embedded tests. The notebook itself should be completely reproducible; from start to finish, another person should be able to use the same code to obtain the same results as yours.  Note that you will receive no more than partial credit if you do not add text/markdown cells explaining your thinking at each major step in each problem.
#
# *Deadline*: Friday, October 21, 12pm. Submit your notebook to Blackboard and push it to your GitHub repository.
#
# ## Setup - obtain data and create database
#
# The US City Open Data Census has data on [restaurant inspections from all over the country](http://us-city.census.okfn.org/dataset/food-safety).  Let's take a look at data from Albuquerque.  *Note*: metadata and other details for this dataset are available at http://data.cabq.gov/business/foodinspections/.
#
# Fyi, to save you a step, I've converted this file into a clean CSV file by using the `dos2unix` command to change its line endings and to switch it to use commas instead of tabs using `csvformat -t inputfile.csv > outputfile.csv`.
#
# First we download the dataset:

# %%
# !wget https://raw.githubusercontent.com/gwsb-istm-6212-fall-2016/syllabus-and-schedule/master/exercises/abq-food-inspections-fy2010.csv
# Out:
# --2016-10-24 00:15:10--  https://raw.githubusercontent.com/gwsb-istm-6212-fall-2016/syllabus-and-schedule/master/exercises/abq-food-inspections-fy2010.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.32.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.32.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5025226 (4.8M) [text/plain]
# Saving to: ‘abq-food-inspections-fy2010.csv’
#
# abq-food-inspection 100%[=====================>]   4.79M  --.-KB/s   in 0.09s
#
# 2016-10-24 00:15:11 (52.4 MB/s) - ‘abq-food-inspections-fy2010.csv’ saved [5025226/5025226]

# %% [markdown]
# ## Problem 1 - examine the data (35 points)
#
# Use `csvstat` and other tools as you see fit and observe its contents.  Review the metadata definitions linked to above.  Describe what you see:  What do all the columns mean?  Are there null values?  Which columns interest you the most?  Which columns present some complications or questions you would like to ask?

# %% [markdown]
# Insert a combination of code and text/markdown cells here to review the data and describe what you find.

# %% [markdown]
# Rename csv file to make it easier to work with

# %%
# !mv abq-food-inspections-fy2010.csv inspections.csv

# %% [markdown]
# Take a look at the columns using csvstat

# %%
# !csvstat inspections.csv
# Out:
#   1. FACILITY_NAME
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 2615
# 	5 most frequent values:
# 		SMITHS FOOD AND DRUG CENTERS INC:	154
# 		ISOTOPES PARK - OVATIONS:	93
# 		PER EHSII CECELIA GARCIA OOB LA REYNA DEL SUR:	85
# 		ISLETA AMPHITHEATER:	68
# 		ECHO INC:	68
# 	Max length: 77
#   2. FACILITY_KEY
# 	<class 'int'>
# 	Nulls: False
# 	Min: 13
# 	Max: 101482
# 	Sum: 820405773
# 	Mean: 46730.79135338346
# 	Median: 50866.0
# 	Standard Deviation: 32659.794578837962
# 	Unique values: 2835
# 	5 most frequent values:
# 		46323:	93
# 		65863:	85
# 		80949:	68
# 		32817:	68
# 		91825:	66
#   3. SITE_ADDRESS
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 2456
# 	5 most frequent values:
# 		1601 AVENIDA CESAR CHAVEZ SE:	94
# 		644 OLD COORS BLVD SW:	85
# 		8601 CENTRAL AV NE:	77
# 		2200 SUNPORT BLVD SE:	75
# 		5210 CENTRAL AV SE:	73
# 	Max length: 35
#   4. CITY
# 	<class 'str'>
# 	Nulls: False
# 	Values: ALBUQUERQUE
#   5. STATE
# 	<class 'str'>
# 	Nulls: False
# 	Values: 87, NM
#   6. ZIP
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 48
# 	5 most frequent values:
# 		87110:	1996
# 		87108:	1976
# 		87102:	1601
# 		87106:	1568
# 		87109:	1552
# 	Max length: 10
#   7. OWNER_KEY
# 	<class 'int'>
# 	Nulls: False
# 	Min: 11
# 	Max: 87302
# 	Sum: 644760848
# 	Mean: 36725.953975848715
# 	Median: 33747.0
# 	Standard Deviation: 29428.207216739836
# 	Unique values: 1892
# 	5 most frequent values:
# 		1838:	792
# 		3537:	321
# 		1272:	228
# 		36280:	156
# 		80274:	155
#   8. OWNER_NAME
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 1852
# 	5 most frequent values:
# 		APS:	792
# 		SMITHS FOOD AND DRUG CENTERS INC:	321
# 		CIRCLE K STORES INC:	277
# 		ALBERTSONS:	228
# 		WAL MART STORES EAST  LP:	156
# 	Max length: 82
#   9. NATURE_OF_BUSINESS
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 594
# 	5 most frequent values:
# 		RESTAURANT:	4994
# 		FOOD SERVICE:	691
# 		GROCERY:	618
# 		BAR/RESTAURANT:	508
# 		APS SCHOOL FOOD SERVICE:	470
# 	Max length: 25
#  10. STREET_NUMBER
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 1349
# 	5 most frequent values:
# 		6600:	216
# 		10000:	152
# 		300:	143
# 		2200:	127
# 		8100:	125
# 	Max length: 7
#  11. STREET_NAME
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 404
# 	5 most frequent values:
# 		CENTRAL:	1898
# 		MENAUL:	928
# 		COORS:	918
# 		MONTGOMERY:	727
# 		SAN MATEO:	707
# 	Max length: 24
#  12. STREET_TYPE
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 13
# 	5 most frequent values:
# 		BLVD:	7636
# 		AV:	3005
# 		ST:	2065
# 		RD:	1900
# 		DR:	995
# 	Max length: 4
#  13. POST_DIRECTIONAL
# 	<class 'str'>
# 	Nulls: True
# 	Values: SW, SE, N, NW, NE
#  14. PHONE
# 	<class 'int'>
# 	Nulls: True
# 	Min: 2471094
# 	Max: 505345566137310
# 	Sum: 2608539289633190
# 	Mean: 161719732773.29138
# 	Median: 5053454060.0
# 	Standard Deviation: 8895791545525.992
# 	Unique values: 2279
# 	5 most frequent values:
# 		9153321301:	101
# 		3037929467:	100
# 		5052224033:	94
# 		3109680646:	85
# 		5052426777:	68
#  15. PROGRAM_CATEGORY
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 25
# 	5 most frequent values:
# 		0406:	7969
# 		0601:	1159
# 		0607:	894
# 		0606:	865
# 		0501:	832
# 	Max length: 4
#  16. PROGRAM_CATEGORY_DESCRIPTION
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 24
# 	5 most frequent values:
# 		Food Service Establishment:	7969
# 		Retail -Grocery:	1159
# 		Retail - Self Service & Prepackage Foods:	894
# 		Retail - Prepackage Only:	865
# 		Bar:	832
# 	Max length: 40
#  17. INSPECTION_DATE
# 	<class 'datetime.date'>
# 	Nulls: False
# 	Min: 2009-07-01
# 	Max: 2010-06-30
# 	Unique values: 258
# 	5 most frequent values:
# 		2009-12-16:	184
# 		2009-09-10:	159
# 		2009-09-25:	148
# 		2009-11-04:	133
# 		2009-10-01:	131
#  18. INSPECTION_TYPE
# 	<class 'NoneType'>
# 	Nulls: True
# 	Values:
#  19. INSPECTION_DESC
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 15
# 	5 most frequent values:
# 		ROUTINE FOOD INSPECTION:	12439
# 		EMERGENCY RESPONSE:	1987
# 		New Business Inspection:	1005
# 		PRE-OPENING FOOD INSPECTION:	743
# 		ADDITIONAL SERVICE PROVIDED:	439
# 	Max length: 32
#  20. SERIAL_NUM
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 9046
# 	5 most frequent values:
# 		DA0045731:	61
# 		DA0047720:	61
# 		DA0047290:	61
# 		DA0045676:	61
# 		DA0059230:	61
# 	Max length: 9
#  21. ACTION_CODE
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 8
# 	5 most frequent values:
# 		11:	14080
# 		00:	2800
# 		09:	382
# 		06:	264
# 		10:	21
# 	Max length: 2
#  22. ACTION_DESC
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 8
# 	5 most frequent values:
# 		APPROVED:	14080
# 		NON-GRADED:	2800
# 		ANNUAL STICKER ISSUED:	382
# 		UNSATISFACTORY:	264
# 		ANNUAL STICKER NOT ISSUED:	21
# 	Max length: 34
#  23. RESULT_CODE
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 19
# 	5 most frequent values:
# 		03:	14389
# 		00:	2416
# 		05:	214
# 		22:	142
# 		18:	104
# 	Max length: 2
#  24. RESULT_DESC
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 19
# 	5 most frequent values:
# 		IN COMPLIANCE:	14389
# 		NOT APPLICABLE:	2416
# 		DOWNGRADE:	214
# 		OUT OF BUSINESS:	142
# 		TRAINING RECEIVED:	104
# 	Max length: 37
#  25. VIOLATION_CODE
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 128
# 	5 most frequent values:
# 		55:	6348
# 		00:	3429
# 		68:	1658
# 		42:	487
# 		35:	441
# 	Max length: 10
#  26. VIOLATION_DESC
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 70
# 	5 most frequent values:
# 		Additional Comments:	6353
# 		No Violations Found:	3434
# 		Delivered Informational Brochure:	1657
# 		Plumbing: Improperly installed/maintained/supplied:	492
# 		Non-Food contact surfaces:	446
# 	Max length: 50
#  27. INSPECTION_MEMO
# 	<class 'NoneType'>
# 	Nulls: True
# 	Values:
#
# Row count: 17556

# %% [markdown]
# The csvstat command above gives us information about each column in the data file. The file has 27 columns to describe the process of inspecting a restaurant. It has 17,556 rows of data.
#
# The first columns are the facility's name and associated key.
#
# The site address, city, state, and zip code follow. Of these, only site address contains null values.
#
# Columns 7 and 8 contain the owner key and the name associate with that key. Column 9 is the nature of the business (such as restaurant or grocery) and it contains some null values.
#
# Columns 10 through 13 break down the site address into street number, street name, street type (whether it is an avenue, road, etc.), and post-directional (whether the address is specified with NW, SE, or other). All of these columns contain null values.
#
# Column 14 contains phone numbers, which are sometimes null. Columns 15 and 16 are the program category key and its description (type of facility permit). The key column does not contain null values but the description does, which is surprising.
#
# Column 17 is the inspection date. Columns 18 and 19 are the inspection type (key) and its description, such as routine or pre-opening inspections. The key column only contains null values.
#
# Column 20 is the serial number associate with the inspection. There are a few serial numbers with very high counts, which I am interested in.
#
# Columns 21 and 22 are the action code and its description (what kind of action was taken such as unable to grade, approve, etc.)
# Columns 23 and 24 are the result code and its description (the result of the inspection, such as downgrade, in compliance, etc.)
# Columns 25 and 26 are the violation code and its description (violations found as a results of inspection, such as none, plumbing, etc.). Both these columns contain null values
#
# Column 27 is the inspection memo, but all its values are null.

# %% [markdown]
# ## Problem 2 - define a database model and load the data (35 points)
#
# Based on what you found above, create and connect to a new database, define a database table in it, and load this dataset into it.  You may use either of the methods for this step you have seen in earlier class notebooks.  You may choose to eliminate variables/columns if they are not relevant or interesting to you - explain your reasoning if you do.  Either way, you should load a majority of the columns present in the source dataset into the database and all of its rows.
#
# Once your data has loaded successfully, run a `COUNT(*)` query to verify that all the data has loaded correctly.
#
# Insert a combination of code and text/markdown cells here to connect to your database, define your table, load its data, and verify the loaded records.

# %% [markdown]
# Restart postgresql

# %%
# !echo 'redspot' | sudo -S service postgresql restart
# Out:
# [sudo] password for jovyan: Restarting PostgreSQL 9.5 database server: main.

# %% [markdown]
# Created the database, activate the sql extension, and connect to database with postgresql

# %%
# !createdb -U dbuser ex4

# %%
# %load_ext sql
# Out:
# /opt/conda/lib/python3.5/site-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# /opt/conda/lib/python3.5/site-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")

# %%
# %sql postgresql://dbuser@localhost:5432/ex4
# Out:
# 'Connected: dbuser@ex4'

# %%
# !csvsql --db postgresql://dbuser@localhost:5432/ex4 --insert inspections.csv

# %% [markdown]
# Drop both columns that contain only null values

# %%
# %%sql
# SELECT column_name, data_type FROM information_schema.columns
# WHERE table_name = 'inspections';
# Out:
# 27 rows affected.
# [('FACILITY_NAME', 'character varying'),
#  ('FACILITY_KEY', 'integer'),
#  ('SITE_ADDRESS', 'character varying'),
#  ('CITY', 'character varying'),
#  ('STATE', 'character varying'),
#  ('ZIP', 'character varying'),
#  ('OWNER_KEY', 'integer'),
#  ('OWNER_NAME', 'character varying'),
#  ('NATURE_OF_BUSINESS', 'character varying'),
#  ('STREET_NUMBER', 'character varying'),
#  ('STREET_NAME', 'character varying'),
#  ('STREET_TYPE', 'character varying'),
#  ('POST_DIRECTIONAL', 'character varying'),
#  ('PHONE', 'bigint'),
#  ('PROGRAM_CATEGORY', 'character varying'),
#  ('PROGRAM_CATEGORY_DESCRIPTION', 'character varying'),
#  ('INSPECTION_DATE', 'date'),
#  ('INSPECTION_TYPE', 'character varying'),
#  ('INSPECTION_DESC', 'character varying'),
#  ('SERIAL_NUM', 'character varying'),
#  ('ACTION_CODE', 'character varying'),
#  ('ACTION_DESC', 'character varying'),
#  ('RESULT_CODE', 'character varying'),
#  ('RESULT_DESC', 'character varying'),
#  ('VIOLATION_CODE', 'character varying'),
#  ('VIOLATION_DESC', 'character varying'),
#  ('INSPECTION_MEMO', 'character varying')]

# %%
# %%sql
# ALTER TABLE inspections
# DROP COLUMN "INSPECTION_MEMO",
# DROP COLUMN "INSPECTION_TYPE";
# Out:
# Done.
# []

# %% [markdown]
# Ensure that the data was loaded correctly. There should be 17,556 rows (one less than the csv file because of the lack of header line)

# %%
# %%sql
# SELECT COUNT(*) FROM inspections;
# Out:
# 1 rows affected.
# [(17556,)]

# %% [markdown]
# ## Problem 3 - explore your data (30 points)
#
# Now that the data is loaded, ask some questions of it!  Identify key variables of interest and note their ranges along with other useful descriptive statistics.  Choose and define a few lines of inquiry, execute queries for each, and describe what you find in your result sets.  Use any query techniques we've seen in class, including aggregate functions, transformations, subqueries, or others as appropriate.
#
# If you find interesting patterns, adding plots to your exploration would be useful.
#
# Insert a combination of code and text/markdown cells here to explore your data.

# %% [markdown]
# First off, are there any restaurants that get inspected a lot?

# %%
# %%sql
# SELECT "FACILITY_NAME", COUNT("SERIAL_NUM") AS num_inspections FROM inspections
# GROUP BY "FACILITY_NAME"
# ORDER BY COUNT("SERIAL_NUM") DESC;
# Out:
# 2615 rows affected.
# [('SMITHS FOOD AND DRUG CENTERS INC', 154),
#  ('ISOTOPES PARK - OVATIONS', 93),
#  ('PER EHSII CECELIA GARCIA OOB LA REYNA DEL SUR', 85),
#  ('ECHO INC', 68),
#  ('ISLETA AMPHITHEATER', 68),
#  ('DIONS PIZZA', 67),
#  ('CIRCLE K 8936', 66),
#  ('OOB CALIFORNIA DEL NORTE ICE CREAM LLC', 65),
#  ('TALIN MARKET WORLD FOOD FARE', 64),
#  ('CIRCLE K 8940', 61),
#  ('OOB MOM THAI FOOD', 61),
#  ('SUBWAY', 60),
#  ('MCDONALDS', 60),
#  ('99 BANH SUPERMARKET', 57),
#  ('OOB SUNFLOWER FARMERS MARKET', 54),
#  ('EL MEZQUITE MARKET LLC', 53),
#  ('OOB  PROS RANCH MARKETS OF ALBUQUERQUE', 52),
#  ('HOT DOG MAN & CO', 51),
#  ('LA PETITE ACADEMY', 48),
#  ('FACILITY OOB 2/28/14 PER EHSII RANDY MARTINEZ THE ICE CREAM MAN', 46),
#  ('OOB RAINBOW ICE CREAM', 43),
#  ('WHOLE FOODS MARKET', 43),
#  ('KEVA JUICE SW LLC', 40),
#  ('OOB GREAT AMERICAN STEAK AND SEAFOOD', 39),
#  ('DIONS', 38),
#  ('BLAKES LOTABURGER', 35),
#  ('WECKS', 34),
#  ("OOB GARDUNO'S RESTAURANT", 33),
#  ('CHILE ADDICT', 32),
#  ('OOB POP N TACO DRIVE UP INC.', 31),
#  ('GARCIAS KITCHEN', 31),
#  ('OOB SOUPER SALAD', 31),
#  ('SONIC DRIVE IN', 30),
#  ('OOB BENCO FOODS INC', 29),
#  ('SMITHS 498', 29),
#  ('CLIFFS', 29),
#  ('LITTLE ANITAS MEXICAN FOOD', 29),
#  ('OOB LA FLOR', 29),
#  ('BURGER KING', 29),
#  ('CARLS JR', 29),
#  ('ALBERTSONS 904', 28),
#  ('SMITHS 439', 27),
#  ('GRAHAM CENTRAL STATION', 27),
#  ('COSTCO WHOLESALE 1016', 26),
#  ('HI LO MARKET', 26),
#  ('CANTEEN OF CENTRAL NM', 25),
#  ('OOB NOTHING BUT NOODLES', 25),
#  ('OOB WILEYS PLACE', 25),
#  ('OOB PER EHSII ZAHRA 01/01/14 DHAKA BAZAAR USA', 25),
#  ('TANOAN COUNTRY CLUB', 25),
#  ('EL MEZQUITE MARKET', 24),
#  ('ALBERTSONS 922', 23),
#  ('OOB DOS HERMANOS', 23),
#  ('SAMS CLUB 4938', 23),
#  ('SUSHI KING LLC', 23),
#  ('OOB GARDUNOS CHILE PACKING CO', 23),
#  ('SMITHS 446', 23),
#  ('VOLCANO VISTA HIGH SCHOOL', 23),
#  ('JOHN BROOKS SUPERMARKET 892', 22),
#  ('WAL MART SUPER CNTR 5430', 22),
#  ('OOB 07.12.13 PWD HYATT REGENCY ALBUQUERQUE', 22),
#  ('OOB SMOKIN DJS', 22),
#  ('COSTCO WHOLESALE 116', 22),
#  ('OOB LITTLE CAESARS', 22),
#  ('SMITHS 463', 22),
#  ('MANZANO HIGH SCHOOL', 22),
#  ('ALBERTSONS 937', 22),
#  ('ALBERTSONS 911', 22),
#  ('OOB CAFE AND BILLIARDS LANG THANG', 22),
#  ('SAMS CLUB 6672', 21),
#  ('SMITHS 496', 21),
#  ('ALBERTSONS 915', 21),
#  ('OOB CAPTAIN DS SEAFOOD', 21),
#  ('OOB SMITHS 429', 21),
#  ('RAINBOW ICE CREAM', 21),
#  ('WAL MART SUPER CENTER 0831', 21),
#  ('ALBERTSONS 905', 21),
#  ('HOTEL ALBUQUERQUE AT OLD TOWN', 21),
#  ('DOMINOS PIZZA', 20),
#  ('TDS SHOW CLUB', 20),
#  ('HOLIDAY INN EXPRESS', 20),
#  ('BANDIDO HIDEOUT INC.', 20),
#  ('HIGHLAND HIGH SCHOOL', 20),
#  ('OOB GARDUNOS OF MEXICO', 20),
#  ('MANZANO HIGH SCHOOL ACTIVITIES', 20),
#  ('SAMS CLUB 4703', 20),
#  ('THE HOME DEPOT - TAX DEPT/L&P', 20),
#  ('OOB DEL NORTE HIGH SCHOOL', 20),
#  ('ALBERTSONS 924', 20),
#  ('ALBERTSONS 939', 19),
#  ('OOB PANADERIA ZARAGOZA', 19),
#  ('CHICADEES', 19),
#  ('OOB PER WRITTEN REQUEST 12/23/13 SCHLOTZSKYS DELI', 19),
#  ('OOB PAPARAZZI', 19),
#  ('DAMACIOS', 18),
#  ('SMITHS 423', 18),
#  ('MCDONALDS RESTAURANT', 18),
#  ('WAL MART SUPER CENTER 835', 18),
#  ('BOBA TEA COMPANY', 18),
#  ('ALBERTSONS 928', 18),
#  ('ALBUQ COUNTRY CLUB', 18),
#  ('OOB BIRD OF PARADISE/JACKS PIZZA', 18),
#  ('PER JOE ANGUIANO FA OOB LONG JOHN SILVERS', 18),
#  ('OOB SUBWAY', 18),
#  ('PER EHSII ZAHRA KANJI FA OOB 5/30/14 FOUR HILLS COUNTRY CLUB', 18),
#  ('RUBENS INC', 18),
#  ('APPLEBEES NEIGHBORHOOD GRILL & BAR', 17),
#  ('OOB 2/26/14ALBERTSONS 908', 17),
#  ('EAST HEIGHTS MOOSE LODGE 2241', 17),
#  ('WAL MART SUPER CENTER 1397', 17),
#  ('OOB SUNFLOWER MARKET', 17),
#  ('OOB GASS AND SAVE', 17),
#  ('ALBERTSONS 938', 17),
#  ('OOB PER EHSII JAY COUSINS 01/23/14 D & H MEAT MARKET & PROCESSING', 17),
#  ('KICKS 66', 17),
#  ('GODIVA CHOCOLATIER INC', 17),
#  ('OOB CARLS JR', 17),
#  ('LOWES 99 SUPERMARKET', 17),
#  ('OOB CENTRAL MARKET', 16),
#  ('INDIA KITCHEN', 16),
#  ('BILLYS LONG BAR', 16),
#  ('STUFYS DRIVE THRU', 16),
#  ('DORADO BAKERY', 16),
#  ('OOB FEDERICOS MEX FOOD', 16),
#  ('OOB PWR 1.16.14 FEI HEALTH CAFE', 16),
#  ('SEASONS ROTISSERIE & GRILL', 16),
#  ('GOLDEN PRIDE CHICKEN', 16),
#  ('FRONTIER RESTAURANT', 16),
#  ('THE BARLEY ROOM', 16),
#  ('OOB PERWRITTEN REQUEST JOHN BROOKS 1312', 16),
#  ('EMBASSY SUITES ALBUQUERQUE', 16),
#  ('CARNICERIA CUAUHTEMOC', 16),
#  ('WAL MART SUPER CENTER 2924', 16),
#  ('WAL MART NEIGHBORHOOD MRKT 3317', 16),
#  ('OOB CAFE TRANG LLC', 15),
#  ('WILSON MIDDLE SCHOOL', 15),
#  ('TRAVEL CENTERS OF AMERICA', 15),
#  ('ST MARTINS HOSPITALITY', 15),
#  ('GRANT MIDDLE SCHOOL', 15),
#  ('WING STOP', 15),
#  ('STANDARD DINER', 15),
#  ('OOB PWD 08.16.13 DOUBLETREE ALBUQUERQUE', 15),
#  ('OOB FAMILIA MEXICANA', 15),
#  ('WAL MART SUPERCENTER 850', 15),
#  ('WAL MART NEIGHBORHOOD MRKT 3385', 15),
#  ('OOB COMANCHE DUKE CITY', 15),
#  ('LUCKY BOY HAMBURGERS', 15),
#  ('ALBQ CHRISTIAN CHILDRENS HOME', 15),
#  ('OOB DOC AND EDDYS', 14),
#  ('OOB BOSTON MARKET', 14),
#  ('SCARPAS', 14),
#  ('OOB PERICOS ACAPULCO', 14),
#  ('SZECHWAN CHINESE RESTAURANT', 14),
#  ('COTTONWOOD CAFE', 14),
#  ('OOB QUARTERS REST AND LOUNGE', 14),
#  ('OOB JDS ICE CREAM', 14),
#  ('AMERICAN LEGION POST 49', 14),
#  ('OOB SIDELINES SPORTS GRILLE', 14),
#  ('DOMINOS', 14),
#  ('OOB LAS MANANITAS RESTAURANT', 14),
#  ('OOB MARKET FRESH CAFE', 14),
#  ('CHUCK E CHEESE PIZZA TIME', 14),
#  ('PAPA MURPHYS', 14),
#  ('OOB LA HACIENDA EXPRESS #4', 14),
#  ('PER EHSII SHANNON BLUEEYES FA OOB 9/15/14 FORTUNE COOKIE', 14),
#  ('DUDS N SUDS', 14),
#  ('PETER PIPER PIZZA', 14),
#  ('COSTCO WHOLESALE CORPORATION', 14),
#  ('HOOTERS ALBUQUERQUE WEST', 14),
#  ('CROWNE PLAZA ALBUQUERQUE', 14),
#  ('JOHN BROOKS SUPERMART 270', 14),
#  ('CHINOS CAFTERIA SERVICES', 14),
#  ('SAVOY BAR & GRILL', 14),
#  ('HECTORS BAKERY', 14),
#  ('OOB SANDIA CHEVRON #2', 14),
#  ('UPTOWN SPORTS GRILL', 14),
#  ('WAFFLE HOUSE', 14),
#  ('IHOP', 13),
#  ('TWIN PEAKS RESTAURANT', 13),
#  ('OOB PER WRITTEN REQUEST 12/23/13 SPECTATORS SPORTS BAR & GRILL', 13),
#  ('RIO GRANDE INN', 13),
#  ('OOB 8/14/13HO HO', 13),
#  ('BARCELONA SUITES', 13),
#  ('PAISANOS ITALIAN RESTAURANT', 13),
#  ('PHO LINH / VIETNAMESE GRILL', 13),
#  ('OOB M & M STORES', 13),
#  ('OOB PUDGE BROS PIZZA', 13),
#  ('KOREAN BBQ HOUSE', 13),
#  ('EASTERN CHILD DEVELOPMENT CENTER', 13),
#  ('CENTURY RIO 24', 13),
#  ('MCM ELEGANTE', 13),
#  ('PUMP N SAVE 49', 13),
#  ('OOB ACADEMIC ANGELS LLC', 13),
#  ('OOB HIGH COUNTRY FOODS INC', 13),
#  ('OOB PER WRITTEN REQUEST QUARTERS WEST RESTAURANT', 13),
#  ('PER EHSII SHANNON BLUEEYES FA OOB 01/01/14 ELLIOTTS', 13),
#  ('BASKIN ROBBINS', 13),
#  ('CHENS CHINESE RESTAURANT', 13),
#  ('CARNICERIA LA ESPECIAL', 13),
#  ('EISENHOWER MIDDLE SCHOOL', 13),
#  ('CHINA INN', 13),
#  ('OOB NANAS TRATTORIA AND PIZZARIA', 13),
#  ('LUCKY LOUNGE', 13),
#  ('PEI WEI ASIAN DINER LLC', 13),
#  ('TARGET STORE T-2031', 13),
#  ('OOB BUSINESS SOLD QUALITY INN & ECONOLODGE', 13),
#  ('OOB FRENCH RIVIERA BAKERY INC', 13),
#  ('EINSTEIN BROS BAGELS 2378', 13),
#  ('OOB PER WRITTEN REQUEST TAJ PALACE INDIAN RESTAURANT', 13),
#  ('OOB ROSYS', 12),
#  ('OOB 04.22.13 AZUMA SUSHI & TEPPAN', 12),
#  ('MALONEYS TAVERN', 12),
#  ('OOB WING BASKET', 12),
#  ('DESERT RIDGE MIDDLE SCHOOL', 12),
#  ('AMERASIA ASIA/SUMO SUSHI', 12),
#  ('ARBYS', 12),
#  ('PAPA FELIPES MEXICAN RESTAURANT', 12),
#  ('BOBS BURGERS', 12),
#  ('CHEVRON', 12),
#  ('COPPER CANYON CAFE', 12),
#  ('EVANGEL CHRISTIAN CENTER', 12),
#  ('OOB WESTGATE LITTLE LEAGUE', 12),
#  ('AUNTIE ANNES', 12),
#  ('DUNKIN DONUTS', 12),
#  ("CONGREGATION B'NAI ISRAEL", 12),
#  ('OOB PER WRITTEN REQUEST K MART', 12),
#  ('OOB LOTUS CAFE', 12),
#  ('THE HORSE & ANGEL TAVERN', 12),
#  ('PHO 1 VIETNAMESE GRILL', 12),
#  ('CHINA WOK', 12),
#  ('JUANITAS COMIDA MEXICANA', 12),
#  ('LA MONTANITA NATL. FOOD COOP.', 12),
#  ('OOB KATHLEEN JAMES HOT DOG STAND', 12),
#  ('OOB SAMURAI GRILL SUSHI BAR', 12),
#  ('SNEAKERZ BAR & RESTAURANT', 12),
#  ('LITTLE CORRAL DAY SCHOOL', 12),
#  ('VFW POST 401 BAR', 12),
#  ('FEDERICOS MEXICAN FOOD 2', 12),
#  ('OOB STEAK GUYS THE', 12),
#  ('OOB SUSHI HANA', 12),
#  ('OOB GUICHOS MEXICAN RESTAURANT', 12),
#  ('LE CHANTILLY FINE PASTRIES', 12),
#  ('BEE HIVE VILLAGE', 12),
#  ('VALERO CORNER STORE 1243', 12),
#  ('ORTEGAS RESTAURANT', 12),
#  ('LABATT NEW MEXICO LLC', 12),
#  ('OOB SENOR MURPHY CANDYMAKER', 12),
#  ('FAIR N SQUARE FOOD STORE', 12),
#  ('OOB 1800S MEXICAN GRILL', 12),
#  ('ROLLING IN DOUGH BAKERY-CAFE', 12),
#  ('ORIGINAL GARCIAS KITCHEN', 12),
#  ('OOB ECONO LODGE', 12),
#  ('CARAVAN EAST NITE CLUB', 12),
#  ('NATIVO LODGE', 12),
#  ('TARGET STORE 357', 12),
#  ('BARNES & NOBLE BOOKSELLERS INC', 12),
#  ('OOB OUR PLAYCE LEARNING CENTER', 12),
#  ('OOB PER TRANSFEROF OWNERSHIP LIBRARY BAR AND GRILL', 11),
#  ('OOB EL SENOR ON THE CORNER CAFE', 11),
#  ('BLACK ANGUS STEAKHOUSE', 11),
#  ('OOB BLUE PLATE SPECIAL', 11),
#  ('7 ELEVEN 705', 11),
#  ('LA MONTANITA FOOD CO OP', 11),
#  ('RUDYS COUNTRY STORE & BBQ', 11),
#  ('GENGHIS GRILL', 11),
#  ('WILSON STADIUM SNACK BAR DECA', 11),
#  ('OOB PER WRITTEN REQUEST 12/23/13 CNM FOOD SERVICE', 11),
#  ('ALBUQUERQUE ACADEMY', 11),
#  ('CLAIM JUMPER', 11),
#  ('OOB MADISON TAYLOR ENTREES', 11),
#  ('OOB YUSIFS', 11),
#  ('OOB ROASTERS KIOSK', 11),
#  ('MONTE CARLO', 11),
#  ('CHOPSTIX', 11),
#  ('LA FAMILIAR RESTAURANT INC', 11),
#  ('CRACKER BARREL OLD COUNTRY 617', 11),
#  ('TARGET STORE 356', 11),
#  ('BODE AERO SERVICE INC.', 11),
#  ('7 ELEVEN 710', 11),
#  ('LOVES TRAVEL STOP 210', 11),
#  ('BLAKES LOTABURGER 6', 11),
#  ('PER EHSII MICHAEL PITTMAN FA OOB 6/26/14 CHILIS GRILL AND BAR 359', 11),
#  ('WAL MART SUPER CENTER 5491', 11),
#  ('HOOVER MIDDLE SCHOOL', 11),
#  ('HOMEWOOD SUITES BY HILTON ABQ UPTOW', 11),
#  ('TULLYS MEAT MARKET', 11),
#  ('WINNING COFFEE CO', 11),
#  ('ZINC', 11),
#  ('TUCANOS BRAZILIAN GRILL', 11),
#  ('EL SARAPE RESTAURANT LLC', 11),
#  ('ZIOS ITALIAN KITCHEN', 11),
#  ('RETROS BAR', 11),
#  ('STAYBRIDGE SUITES AIRPORT', 11),
#  ('OOB BRICKYARD PIZZA', 11),
#  ('SHOGUN JAPANESE RESTAURANT', 11),
#  ('OOB MYKONOS CAFE', 11),
#  ('SHERATON UPTOWN HOTEL', 11),
#  ('CIBOLA HIGH SCHOOL', 11),
#  ('HINKLE FAMILY FUN CENTER', 11),
#  ('OLYMPIA CAFE', 11),
#  ('OOB CAFE CAFE', 11),
#  ('OOB RADISSON RESORT HOTEL', 11),
#  ('CARRAROS RESTAURANT', 11),
#  ('APPLEBEES GRILL AND BAR 6406', 11),
#  ('EL POLLO REAL COLOMBIANO', 11),
#  ('7 ELEVEN 708', 11),
#  ('TGI FRIDAYS', 11),
#  ('TACO CABANA', 11),
#  ('BEST LEES INC', 11),
#  ('TRATTORIA TROMBINOS', 11),
#  ('JIMMY CARTER MIDDLE SCHOOL', 11),
#  ('EAT FIRST CHINESE RESTAURANT', 11),
#  ('HASTINGS ENTERTAINMENT', 11),
#  ('OOB JOHN MARSHALL SR CENTER', 11),
#  ('VILLA PIZZA INC', 11),
#  ('OOB LEISURE BOWL', 11),
#  ('HOOTERS RESTAURANT', 10),
#  ('OOB GAS EXPRESS', 10),
#  ('DONUT MART', 10),
#  ('PER OWNER FA OOB 9/30/12 LE PARIS FRENCH BAKERY', 10),
#  ('TARGET STORE 625', 10),
#  ('APACHE ELEMENTARY', 10),
#  ('WEST MESA HIGH SCHOOL', 10),
#  ('SATELLITE', 10),
#  ('FIESTAS RESTAURANT AND LOUNGE', 10),
#  ('THAI HOUSE', 10),
#  ('ARBYS ROAST BEEF', 10),
#  ('OLIVE GARDEN', 10),
#  ('MCDONALDS 5553', 10),
#  ('COACHES CORNER ELDORADO GYM', 10),
#  ('7 ELEVEN 712', 10),
#  ('HAWAIIAN GRILL', 10),
#  ('OOB JASONS DOWNTOWN', 10),
#  ('HIGH NOON SALOON', 10),
#  ('OOB KNUCKLEHEADS BAR & GRILL', 10),
#  ('OOB ZEA ROTISSERIE GRILL', 10),
#  ('ARROW SUPERMARKET', 10),
#  ('OOB RALLIS 4TH ST PUB & GRILL', 10),
#  ('THE CUBE RESTAURANT', 10),
#  ('BUFFALO WILD WINGS GRILL & BAR', 10),
#  ('PER EHSII ZAHRA KANJI FA OOB 4/30/13 DAGMARS STRUDEL HOUSE CAFE & BAKERY', 10),
#  ('JAMES MONROE MIDDLE SCHOOL', 10),
#  ('OOB BLACK MESA COFFEE CO', 10),
#  ('CICIS PIZZA', 10),
#  ('NELSON MEATS', 10),
#  ('SANDIA HIGH SCHOOL', 10),
#  ('OOB FUZZYS TACO SHOP', 10),
#  ('SANDIA COURTYARD HOTEL AND CC', 10),
#  ('OOB 3.15.13 HOLIDAY INN HOTEL AND SUITES', 10),
#  ('FARMERS MARKET', 10),
#  ('ALLSUPS 218', 10),
#  ('OOB THE CHILI EXPRESS', 10),
#  ('OOB 10.30.13 DEL TACO', 10),
#  ('OOB STADIUM VALUE-WAY #226', 10),
#  ('CHILIS GRILL & BAR 419', 10),
#  ('KRUNG THAI REST', 10),
#  ('AZUSA CHRISTIAN FAITH ASSEMBLY', 10),
#  ('OOB CANCUN MEXICAN RESTAURANT #1', 10),
#  ('BLAKES LOTABURGER 14', 10),
#  ('MEXICO LINDO', 10),
#  ('OOB DENNYS 6419', 10),
#  ('ALBUQUERQUE MARRIOTT PYRAMID NORTH', 10),
#  ('OOB PER WRITTEN REQUEST 11/15/13 PALOMA BLANCA HLTH & REHAB', 10),
#  ('ARBYS / TJ CINNAMONS', 10),
#  ('PER EHSII SHANNON BLUEEYES FA OOB 6/30/14 RED ROBIN', 10),
#  ('ALLSUPS 198', 10),
#  ('PER EHSII MICHAEL PITTMAN FA OOB 8/8/14 FOX & HOUND SMOKEHOUSE & TAVERN', 10),
#  ('OOB CESAR CHAVEZ COMMUNITY SCHOOL', 10),
#  ('MONROES', 10),
#  ('OOB MIDTOWN DEPOT', 10),
#  ('LOVELACE MEDICAL CENTER', 10),
#  ('PER EHSII SHANNON BLUEEYES FA OOB 7/15/14 RED LOBSTER 6280', 10),
#  ('VILLA DI CAPO', 10),
#  ('MARCELLOS CHOPHOUSE', 10),
#  ('APPLEBEES GRILL AND BAR 6402', 10),
#  ('ALBUQ HIGH SCHOOL DECA CLUB', 10),
#  ('CHICHARRONERIA DON CHOCHE', 10),
#  ("OOB MIGUELITO'S", 10),
#  ('TACO DE MEXICO', 10),
#  ('OOB DOLLAR TREE #2653', 10),
#  ('OOB INDOPAK MORE THAN A STORE', 10),
#  ('OOB INDEPENDENCE GRILL', 10),
#  ('SOUTHWEST CHILD CARE', 10),
#  ('GECKOS BAR TAPAS 2', 10),
#  ('OOB JERSEY JACKS EATERY', 10),
#  ('OOB 8/27/13 VALLEY HS ACTIVITIES SNACK BAR', 10),
#  ('OOB CIRCLE K 5317', 10),
#  ('OOB T L C BAKERY', 10),
#  ('OOB CORRAL MEXICAN FOOD', 10),
#  ('OOB ICE CREAM RICA', 10),
#  ('OOB SUBWAY 14268 JB', 10),
#  ('OOB SAVEWISE FOODS INC', 10),
#  ('BURRITO LADY  THE', 10),
#  ('OOB BEN & JERRYS ICE CREAM', 10),
#  ('MCKINLEY MIDDLE SCHOOL', 10),
#  ('OOB PER WRITTEN REQUEST MILTONS RESTAURANT INC', 10),
#  ('OOB PER REQUESTNEW CHINA', 10),
#  ('OOB QUIZNOS SUB', 10),
#  ('ALBUQUERQUE MARRIOTT', 10),
#  ('MARIOS PIZZA', 10),
#  ('OOB PER EHSII TAMI 01/19/14 CHARLIES FRONT DOOR KITCHEN', 10),
#  ('ARIRANG ORIENTAL MARKET', 10),
#  ('CLEVELAND MIDDLE SCHOOL', 10),
#  ('JASONS DELI', 10),
#  ('TEXAS ROADHOUSE HOLDING LLC', 10),
#  ('OOB ALBUQUERQUE TORTILLA INC.', 10),
#  ('NAVAJO LODGE 863', 10),
#  ('KELLERS FARM STORES', 10),
#  ('SAKURA SUSHI', 10),
#  ('KIMS ORIENTAL MARKET', 10),
#  ('TIMES SQUARE DELI MART', 9),
#  ('SANDIA CHILE GRILL', 9),
#  ('ANDALUZ RESTAURANT KITCHEN', 9),
#  ('ROADRUNNER CHILD DEVELOPMENT', 9),
#  ('OOB DUKES STEAK HOUSE', 9),
#  ('BRAVO CUCINA ITALIANA', 9),
#  ('OOB FREMONTS FINE FOODS', 9),
#  ('OOB ALAMEDA CHEVRON', 9),
#  ('OOB LOS PUENTES CHARTER SCHOOL', 9),
#  ('OOB PACIFIC RIM', 9),
#  ('CHEZ AXEL', 9),
#  ('LINDYS COFFEE SHOP', 9),
#  ('OOB HO LO MA CHINESE RESTAURANT', 9),
#  ('DIONS PIZZA COMMISSARY', 9),
#  ('OOB PER NEW OWNERSHIP FUDDRUCKERS', 9),
#  ('LA ACADEMIA DE LENGUA Y CULTUR', 9),
#  ('ROMANOS MACARONI GRILL', 9),
#  ('OOB PER EHSII ROSANNA 11/30/13 SUBWAY', 9),
#  ('EAST GATE KIDS CHILD CARE', 9),
#  ('POWDRELLS BAR B Q', 9),
#  ('OOB08/16/13PUPUSERIA Y MINI RESTAURANT', 9),
#  ('OOB PER WRITTEN REQUEST SIZZLER FAMILY STEAK HOUSE', 9),
#  ('PANDA EXPRESS', 9),
#  ('OOB ARCHDIOCESE OF SANTA FE CAFETERIA', 9),
#  ('PRECIOUS MOMENTS CHILDCARE CTR', 9),
#  ('LOS CUATES EAST', 9),
#  ('ARROYO DEL OSO GOLF COURSE', 9),
#  ('OOB THAI EXPRESS LLC', 9),
#  ('YDI HEADSTART/KIRTLAND', 9),
#  ('CHURCHS CHICKEN 2020', 9),
#  ('OOB ENCHANTMENT CHOCOLATES', 9),
#  ('BLACKBIRD BUVETTE', 9),
#  ('COURTYARD BY MARRIOTT', 9),
#  ('SMG', 9),
#  ('GRUET WINERY', 9),
#  ('CHALIOS MEXICAN FOOD', 9),
#  ('CHINA BUFFET NM INC', 9),
#  ('KINDER QUEST INC', 9),
#  ('JEFFERSON MIDDLE SCHOOL', 9),
#  ('CARNICERIA CHIHUAHUA', 9),
#  ('OOB CHILLY WILLYS ITALIAN ICE', 9),
#  ('OOB WATER ZONE', 9),
#  ('TRUMAN MIDDLE SCHOOL', 9),
#  ('OOB WESTGATE LITTLE LEAGUE @ 86TH ST', 9),
#  ('PF CHANGS CHINA BISTRO', 9),
#  ('MEALS ON WHEELS', 9),
#  ('DUKE CITY GOURMET', 9),
#  ('MALARKYS', 9),
#  ('OLIVE GARDEN 118', 9),
#  ('CAMINO RETIREMENT APARTMENTS', 9),
#  ('FLYING STAR 5', 9),
#  ('PELICANS RESTAURANT OF ALBUQ', 9),
#  ('HOWIES SPORTS PAGE', 9),
#  ('BEST WESTERN EXECUTIVE SUITES', 9),
#  ('IHOP 1550', 9),
#  ('QUALITY FOODS INC', 9),
#  ('LOWES SUPER SAVE GROCERY 98', 9),
#  ('EL BRONCO RESTAURANT', 9),
#  ('OOB HO HO CENTRAL', 9),
#  ('OOB SWISS ALPS BAKERY', 9),
#  ('COMIDA BUENA', 9),
#  ('SUBWAY SANDWICHES & SALADS', 9),
#  ('HEIGHTS CLUB', 9),
#  ('OOB TACO ALLENDE', 9),
#  ('YANNIS BAR AND GRILL', 9),
#  ('CINNABON', 9),
#  ('LONE STAR STEAKHOUSE AND SALOON', 9),
#  ('OOB CITIBANK ARAMARK', 9),
#  ('ILLEGAL VENDORS A1A', 9),
#  ('OOB SUBWAY SANDWICHES', 9),
#  ('NOAHS ARK CHILDRENS CENTER', 9),
#  ('OOB GREAT WALL CHINESE RESTAURANT', 9),
#  ('OOB PER WRTN RQST TERIYAKI KITCHEN CO', 9),
#  ('CHAMA RIVER BREWING COMPANY', 9),
#  ('HOMEWOOD SUITES ALBUQUERQUE AIRPORT', 9),
#  ('FAITH LUTHERAN CHURCH', 9),
#  ('PER EHSII MICHAEL PITTMAN FA OOB 7/1/14 BOSTONS GOURMET PIZZA', 9),
#  ('OOB ALBUQUERQUE PRODUCE EXCHANGE', 9),
#  ('OOB SMOOTHIE KING', 9),
#  ('JINJA BAR AND BISTRO', 9),
#  ('OOB OUTBACK STEAKHOUSE', 9),
#  ('PER EHSII ROSANNA TRUJILLO FACILITY OOB 8/20/14 RED LOBSTER RESTAURANT 291', 9),
#  ('TRADER JOES 166', 9),
#  ('MANZANO MESA MULTI-GEN CTR', 9),
#  ('OOB GOLDEN SWIRL / TROPICANA', 9),
#  ('KENNEDY MIDDLE SCHOOL', 9),
#  ('VALLEY HIGH SCHOOL', 9),
#  ('SWEET TOMATOES COMMISSARY', 9),
#  ('BIG 5 NEW MEXICO INC', 9),
#  ('MARY AND TITOS CAFE', 9),
#  ('KELLERS FARM STORE', 9),
#  ('JACKSON MIDDLE SCHOOL', 9),
#  ('OOB HAWAIIAN SHAVED ICE HSI VENDOR SRVS', 9),
#  ('OOB CIRCLE K 6299', 9),
#  ('OOB SAMURAI GRILL & SUSHI BAR LLC', 9),
#  ('DEES CHEESECAKE FACTORY', 9),
#  ('OOB WIENERSCHITZEL #523', 9),
#  ('PHILLIPS 66 / ROBERTS OIL', 9),
#  ("OOB BERTHA'S KITCHEN MEXICAN FOOD", 8),
#  ('LA PASADA HALFWAY HOUSE', 8),
#  ('SUNSET GRILLE & BAR', 8),
#  ('PER EHSII TAMI HASTING FA OOB 05/2013 WAY OUT WEST CINNAMON', 8),
#  ('FRUIT BASKET', 8),
#  ('JAPANESE KITCHEN', 8),
#  ('OOB DONUT MART', 8),
#  ("OOB SHONEY'S", 8),
#  ('SONIC DRIVE IN OF ALBQ 1', 8),
#  ('CAFE ISTANBUL', 8),
#  ('SERENDIPITY DAY SCHOOL', 8),
#  ('JERIS CAFE', 8),
#  ('ST MARKS IN THE VALLEY', 8),
#  ('ANTIQUITY RESTAURANT  INC.', 8),
#  ('HAWTHORN INN AND SUITES', 8),
#  ('CONGREGATION ALBERT', 8),
#  ('CHILIS GRILL & BAR 757', 8),
#  ('CORONADO ELEMENTARY', 8),
#  ('PAPPADEAUX', 8),
#  ('OOB TACO BELL 3218', 8),
#  ('OOB CHINA BEST NM INC', 8),
#  ('APS CENTRAL KITCHEN', 8),
#  ('OOB GARDUNOS MARGARITA FACTORY', 8),
#  ('OOB SAMANTHAS PRODUCE AND MORE', 8),
#  ('KINGDOM BUILDERS PRE SCHOOL', 8),
#  ('BLAKES LOTABURGER 44', 8),
#  ('TONY HILLERMAN MIDDLE SCHOOL', 8),
#  ('OOB PER EHD SUBWAY', 8),
#  ('OOB GOLDEN BIRD CHINESE CUISINE', 8),
#  ('KIKKA @ WHOLE FOODS MARKET', 8),
#  ('MANNIES FAMILY RESTAURANT INC', 8),
#  ('PER EHSII RANDY MARTINEZ FA OOB 7/25/14 THE COPPER LOUNGE KITCHEN', 8),
#  ('ROUTE 66 DONUT & BAGEL EXPRESS', 8),
#  ('NEW FUTURES SCHOOL', 8),
#  ('CHILIS GRILL & BAR 111', 8),
#  ('AMERICAN LEGION POST 13', 8),
#  ('OOB CARNICERIA LOS NOGALES', 8),
#  ('OOB SOUTHWEST GIFT BASKETS', 8),
#  ('FAMILY DOLLAR STORES OF NM 5120', 8),
#  ('OOB 10.30.13 DEL TACO 898', 8),
#  ('ARAMARK AT FIDELITY INVESTMENTS', 8),
#  ('ROBERTS OIL 34', 8),
#  ('OOB GOURMET TO GO', 8),
#  ('HILTON GARDEN INN ABQ UPTOWN', 8),
#  ('STARBUCKS COFFEE 10119', 8),
#  ('OOB LA DOLCE VITA', 8),
#  ('SANDIA LEARNING CENTER', 8),
#  ('POPEYES CHICKEN & BISCUITS', 8),
#  ('TERIYAKI CHICKEN BOWL 3', 8),
#  ('APPLEBEES GRILL AND BAR 6401', 8),
#  ('TWISTERS GRILL 3', 8),
#  ('EAST OCEAN', 8),
#  ('PIZZA HUT 012963', 8),
#  ('SCHLOTZSKYS', 8),
#  ('CIRCLE A CONVENIENCE', 8),
#  ('OOB PER WRITTEN REQUEST 5/6/14 SAMI FOOD MART', 8),
#  ('OOB YOGO BERRY', 8),
#  ('OOB SABROSO NORTHERN NEW MEXICAN GR', 8),
#  ('RODOLFO ANAYA ELEMENTARY', 8),
#  ('OLIVE GARDEN 1602', 8),
#  ('STONE FACE TAVERN', 8),
#  ('OOB LA HACIENDA REST/LOUNGE', 8),
#  ('APPLEBEES GRILL AND BAR 6405', 8),
#  ('FA OOB 12/31/13 PER EHSII TAMIS HASTINGS OUT WEST EATERIES DBA ROPERS RESTAU', 8),
#  ('OOB CAROM CLUB LLC', 8),
#  ('CHILIS GRILL & BAR 1191', 8),
#  ('RANGE CAFE THE', 8),
#  ('MARY ANN BINFORD ELEMENTARY', 8),
#  ('BIG LOTS', 8),
#  ('PER EHSII ZAHRA KANJI FA OOB 3/30/14 KINDER CARE 1038', 8),
#  ('DURAN CENTRAL PHARMACY', 8),
#  ('SAVORY FARE', 8),
#  ('CHOW FUN COORS LLC', 8),
#  ('OOB 8/19/14 PER EHSII MICHAEL PITTMAN RED ROBIN RESTAURANT', 8),
#  ('M AND M STORES NO 3', 8),
#  ('SONIC DRIVE IN 8', 8),
#  ('TRADER JOES 167', 8),
#  ('SUBWAY ENTERPRISES', 8),
#  ('ARTICHOKE CAFE', 8),
#  ('WASHINGTON MIDDLE SCHOOL', 8),
#  ('LOYAL ORDER OF MOOSE 1517', 8),
#  ('OOB GREGORIOS ITALIAN KITCHEN', 8),
#  ('OOB THAI HOUSE', 8),
#  ('DESERT GREENS GOLF COURSE INC', 8),
#  ('CHILIS BAR & GRILL', 8),
#  ('OOB THE MELTING POT', 8),
#  ('HAWTHORNE CHILD DEVELOPMENT CENTER', 8),
#  ('BUCA DI BEPPO', 8),
#  ('YDI MESA VERDE HEADSTART', 8),
#  ('RESIDENCE INN ALB AIRPORT', 8),
#  ('OOB INDIA PALACE RESTAURANT', 8),
#  ('LA MEXICANA HOT TAMALE', 8),
#  ('GARFIELD MIDDLE SCHOOL', 8),
#  ('OOB CIRCLE K 6169', 8),
#  ('OOB CUPCAKEOLOGY LLC', 8),
#  ('FIESTA BVRGE INC RIO', 8),
#  ('BLAKES LOTABURGER 72', 8),
#  ('RUBENS GRILL', 8),
#  ('PER EHSII TAMI HASTINGS FA OOB 8/29/14 ELEPHANT BAR RESTAURANT', 8),
#  ('VAN BUREN MIDDLE SCHOOL', 8),
#  ('HASTINGS BOOKS MUSIC & VIDEO', 8),
#  ('HASTINGS BOOKS & RECORDS', 8),
#  ('CASA DE FIESTA', 8),
#  ('OOB PER WRITTEN REQUEST 12/2/13 NICKS PLACE', 8),
#  ('BLAKES LOTABURGER 68', 8),
#  ('BILLIARD PALACE', 8),
#  ('OOB CIRCLE K 8943', 8),
#  ('GECKOS BAR & TAPAS', 8),
#  ('AMERICAN LEGION POST 99', 8),
#  ('ARIANA HALAL MARKET INC', 8),
#  ('OOB OUR LADY OF THE ASSUMPTION', 8),
#  ('OOBCOMFORT INN EAST', 7),
#  ('OOB 7/1/14 CARLISLE 66/SUBWAY', 7),
#  ('CAFE GREEN', 7),
#  ('OOB TACOS NOELIA', 7),
#  ('OOB JUAN TABO FOOD MART LLC', 7),
#  ('APPLEBEES GRILL AND BAR 6403', 7),
#  ('OOB PER WRITTEN REQUEST HAPPY JAY', 7),
#  ('CANTEEN JOURNAL CENTER', 7),
#  ('PER EHSII ZAHRA KANJI FA OOB 4/30/13 BAMBOO HOUSE CHINESE RESTAURANT', 7),
#  ('OOB JULIAS NEW MEXICAN & VEGT CAFE', 7),
#  ('SUBWAY 17087 JB', 7),
#  ('YDI CHICO GEN BRADLEY', 7),
#  ('EL VIVA MEXICO RESTAURANT', 7),
#  ('BEST WESTERN AIRPORT INN', 7),
#  ('WALGREENS 09773', 7),
#  ('OOB FIRST BAPTIST CHURCH', 7),
#  ('GIANT 6035', 7),
#  ('QUALITY SUITES', 7),
#  ('ROBERTS OIL CO 18', 7),
#  ('OOB BUMBLEBEES BAJA GRILLS INC', 7),
#  ('OOB SWIFTYS RED HOTS', 7),
#  ('OOB UNITED ARTISTS THEATRES', 7),
#  ('OOB OUR LADY OF FATIMA - APS', 7),
#  ('PLAY TO LEARN', 7),
#  ('SANDIA BASE ELEMENTARY  PTA', 7),
#  ('MIMMOS PIZZA', 7),
#  ('GIANT 840', 7),
#  ('TWISTERS', 7),
#  ('OOB GOLD STREET CAFE', 7),
#  ('OOB PER WRITTEN REQUEST 1/17/14 COSMO TAPAS RESTAURANT', 7),
#  ('OOB MONICAS RESTAURANT', 7),
#  ('GAS MAX', 7),
#  ('EL TACO TOTE', 7),
#  ('OOB NEW MEXICO BANQUET CATERING INC', 7),
#  ('CALIFORNIA PIZZA KITCHEN INC', 7),
#  ('QUARTERS REST & LOUNGE', 7),
#  ('OOB COACHES SPORTS GRILL', 7),
#  ('ANODYNE', 7),
#  ('EINSTEIN BROS BAGELS 2345', 7),
#  ('OOB WHATABURGER #245', 7),
#  ('MILLYS RESTAURANT', 7),
#  ('ALVARADO DAY SCHOOL INC', 7),
#  ('OOB CIRCLE K 6118', 7),
#  ('OOB PER WRITTEN REQUEST MARISCOS LA PLAYA', 7),
#  ('BLAKES LOTABURGER 56', 7),
#  ('WALGREENS 4047', 7),
#  ('OOB CAKE FETISH', 7),
#  ('OOB M & S FOODS', 7),
#  ('NICK AND JIMMYS BAR AND GRILL', 7),
#  ('GIANT 844', 7),
#  ('OOB SIDEWINDERS RANCH', 7),
#  ('SUBWAY MONTGOMERY', 7),
#  ('OOB PER WRITTEN REQUEST TOKYO JAPANESE  MARKET', 7),
#  ('ALAM LLC - RETAIL', 7),
#  ('OOB 05.02.13 PWD QUALITY INN AND SUITES', 7),
#  ('JOHN ADAMS MIDDLE SCHOOL', 7),
#  ('OOB EVERGREEN CHINESE BUFFET', 7),
#  ('OOB05/07/12LA PALOMA MEXICAN FOOD', 7),
#  ('SOLO CLUB FOOD SVC.', 7),
#  ('OOB RALPH J BUNCHE ACADEMY', 7),
#  ('WEST MESA MARKET', 7),
#  ('BEAR CANYON SENIOR CTR', 7),
#  ('WOOL WAREHOUSE', 7),
#  ('YDI EMBUDO', 7),
#  ('OOB 11.19.14 PWD LE PEEP RESTAURANT', 7),
#  ('SLATE AT THE MUSEUM', 7),
#  ('PER EHSII TAMI HASTINGS OOB 12/05/13 CORNER STORE 1245', 7),
#  ('PER EHSII TAMI HASTINGS FA OOB 4/23/13 CORNER STORE 1225', 7),
#  ('MACS STEAK N ROUGH', 7),
#  ('CHEBA HUT TOASTED SUBS', 7),
#  ('DAYS INN EAST', 7),
#  ('OOB CARESTONE AT QUINTESSENCE', 7),
#  ('OOB NO BOUNDARIES GOURMET FOODS LLC', 7),
#  ('OOB NEW MEXICO FINE FOODS', 7),
#  ('OOB 8/14/13CIRCLE K 6134', 7),
#  ('CHURCHS CHICKEN', 7),
#  ('SANSEI CORONADO INC', 7),
#  ('BLAKES LOTABURGER 9', 7),
#  ('OOB THE WHOLE ENCHILADA', 7),
#  ('OOB WENDYS 7', 7),
#  ('MCDONALDS 364', 7),
#  ('OOB BIRRIERIA Y TAQUERIA EL ALEX', 7),
#  ('OOB 7.10.13 DAYS INN', 7),
#  ('JACK IN THE BOX', 7),
#  ('OOB SWEET BLESSING BAKERY CAFE/CATERING', 7),
#  ('OOB UNITED ARTISTS FOUR HILLS 10', 7),
#  ('LA MESA ELEMENTARY', 7),
#  ('COOPERAGE  THE', 7),
#  ('FLYING STAR 4', 7),
#  ('7 ELEVEN 57722', 7),
#  ('ALL SEASONS CHILD CARE 402', 7),
#  ('PDQ CONVENIENCE STORE', 7),
#  ("OOB DEE DEE'S ICE CREAM SHOP", 7),
#  ('GREAT FORTUNE CHINESE RESTAURA', 7),
#  ('OOB PER WRITTEN REQUEST DAIRY QUEEN 3', 7),
#  ('HEAVEN DRAGON', 7),
#  ('OOB CIRCLE K 8936', 7),
#  ('NOB HILL BAR AND GRILL LLC', 7),
#  ('SCALO', 7),
#  ('TWO FOOLS TAVERN LLC', 7),
#  ('OOB VALLEY CONOCO REDIMART', 7),
#  ('OOB JIMMY CARTER MID SCH SNACK BAR', 7),
#  ('PER EHSII CECELIA GARCIA FA OOB 5/23/14 FEDERICOS MEXICAN FOOD', 7),
#  ('OOB NICE N FRESH', 7),
#  ('PER TREASURY FA OOB 6/13 TRAVELODGE', 7),
#  ('PER EHSII ROSANNA TRUJILLO FA OOB 02/20/14 VALERO', 7),
#  ('OOB PER WRITTEN REQUEST 11/27/13 HELLO DELI', 7),
#  ('SALVATION ARMY KITCHEN', 7),
#  ('SCHLOTZSKYS STORES LLC', 7),
#  ('SHANDIIN CHILD DEVELOPMENT CENTER', 7),
#  ('SUBWAY 13624', 7),
#  ('FAMILY DOLLAR STORES OF NM 5328', 7),
#  ('AMERICAS BEST VALUE INN', 7),
#  ('OOB SHERATON ALBUQUERQUE AIRPORT HOTEL', 7),
#  ('HOLIDAY INN SELECT', 7),
#  ('SWH MIMIS CAFE LLC', 7),
#  ('FAMILY DOLLAR STORES OF NM 2828', 7),
#  ('OOB RELISH LLC', 7),
#  ('OOB BLUE JEANS LOUNGE AND RESTAURANT', 7),
#  ('CLUB DEMONSTRATION SERVICES', 7),
#  ('ATRIA VISTA DEL RIO LLC', 7),
#  ('CHINA GARDEN', 7),
#  ('CHURCH STREET CAFE', 7),
#  ('MCCOLLUM ELEMENTARY', 7),
#  ('PRESBYTERIAN HOSP KITCHEN/DRS', 7),
#  ('K MART 3444', 7),
#  ('WALGREENS 09213', 7),
#  ('OOB ALBUQUERQUE MEMORY CARE COMMUNITY L', 7),
#  ('LOUIES PUB & GRILL', 7),
#  ('HOTEL BLUE THE', 7),
#  ('CHAPARRAL ELEMENTARY', 7),
#  ('OOB BAMBINOS PIZZA', 7),
#  ('SADIES DINING ROOM', 7),
#  ('MOR FURNITURE FOR LESS', 7),
#  ('SUNSET VIEW ELEMENTARY', 7),
#  ('OOB JRS BAR BQ COMMISSARY', 7),
#  ('OOB CIRCLE K 8942', 7),
#  ('PER EHSII SHANNON BLUEEYES FA OOB 12/18/13 KAIS CHINESE RESTAURANT', 7),
#  ('PER EHSII SHANNON BLUEEYES FA OOB 8/31/13 BASKIN ROBBINS', 7),
#  ('SUSHI HAMA', 7),
#  ('OOB HOUSE OF PHO', 7),
#  ('GIANT 6020', 7),
#  ('OOB SMOKIN DJS#2 AT T MOBILE', 7),
#  ('LOTUS NIGHTCLUB', 7),
#  ('OOB THAI CRYSTAL', 7),
#  ('OOB MI RANCHO', 7),
#  ('OOB WESTSIDE CAFE', 7),
#  ('MARBLE BREWERY', 7),
#  ('TWISTERS GRILL 14', 6),
#  ('MEXICAN FOOD BY MUJERES EN ACCION', 6),
#  ('OOB PER WRITTEN REQUEST 12/23/13 CHRISTYS FOOD FACTORY', 6),
#  ('ONIELLS PUB INC', 6),
#  ('OOB CHOCOLATE CAFE AND BAKERY', 6),
#  ('SBARRO ITALIAN EATERY', 6),
#  ('LA MESA EARLY HEAD START', 6),
#  ('OOB CAJUN KITCHEN THE', 6),
#  ('OOB DUKE CITY FUELING', 6),
#  ('7 ELEVEN 707', 6),
#  ('BLAKES LOTABURGER 35', 6),
#  ('OOB DENNYS', 6),
#  ('FLYING STAR 1', 6),
#  ('SINGING ARROW CHILD DEV CTR', 6),
#  ('KOA', 6),
#  ('ALTA MONTE CHILD DEVEL CENTER INC', 6),
#  ('OOB CIRCLE K 1313', 6),
#  ('SONIC DRIVE IN 2', 6),
#  ('OOB CIRCLE K 7962', 6),
#  ('OOB BONNIES BREAKFAST CLUB', 6),
#  ('CIBOLA -DECA SNACK BAR', 6),
#  ('HYATT PLACE', 6),
#  ('PAPA JOHNS PIZZA 1345', 6),
#  ('OOB BUBBLE TEA AND COFFEE', 6),
#  ('HOT DOGS Y ELOTES EL AGUILA', 6),
#  ('OOB PERK UP ESPRESSO LLC', 6),
#  ('OOB CIRCLE K 8940', 6),
#  ('TERIYAKI CHICKEN BOWL 4', 6),
#  ('CHILDRENS PROMISE CENTERS', 6),
#  ('OOB PER NEW OWNERSHIP ECONO LODGE', 6),
#  ('TWISTERS GRILL 13', 6),
#  ('PHILLIPS 66', 6),
#  ('TWISTERS 18', 6),
#  ('PER EHSII TAMI HASTINGS FA OOB 01/31/14 MAY HONG', 6),
#  ('CLAUDIA RAES', 6),
#  ('OOB ZENITH FASHIONS', 6),
#  ('OOB CAFE CHORONI', 6),
#  ('PIZZA HUT 012951', 6),
#  ('OOB MOS TAILGATE CAFE', 6),
#  ('7 ELEVEN 718', 6),
#  ('EL SABOR DE JUAREZ', 6),
#  ('EINSTEIN BROS BAGELS 1193', 6),
#  ('MARIOS PIZZA AND PASTA EXPRESS INC', 6),
#  ('BOBS BURGERS 4', 6),
#  ('OOB CHURCHILL CHEVRON REDIMART', 6),
#  ('OOB LA HACIENDA BURRITO EXPRESS', 6),
#  ('OOB STUFYS TO GO', 6),
#  ('LA CREPE MICHEL', 6),
#  ('OOB SWEET FACTORY #3141', 6),
#  ('LOUIES MEXICAN RESTAURANT', 6),
#  ('PAULS MONTEREY INN  INC.', 6),
#  ('PER EHSII SHANNON BLUEEYES FA OOB 3/31/14 ALL OUT SUSHI', 6),
#  ('ALBUQUERQUE HIGH SCHOOL', 6),
#  ('OOB JASMINE THAI & SUSHI HOUSE', 6),
#  ('SONIC DRIVE IN 13', 6),
#  ('PRECIOUS MOMENTS CHILDCARE', 6),
#  ('RIO GRANDE PRES CHURCH', 6),
#  ('CLUBHOUSE INN SUITES', 6),
#  ('VOLCANO VISTA DECA', 6),
#  ('OOB ANTOJITOS EL JEFE', 6),
#  ('DOLLAR GENERAL STORE 10188', 6),
#  ('CERVANTES MEXICAN FOODS INC', 6),
#  ('7 ELEVEN 714', 6),
#  ('DILLARDS', 6),
#  ('BUFFALO WILD WINGS GRILL AND BAR', 6),
#  ('EMERSON CHILD DEVELOPMENT', 6),
#  ('OOB GEOS MOBILE BISTRO', 6),
#  ('OOB03/29/11LOS CUATES SOUTH', 6),
#  ('VINCENT E GRIEGO CHILD DEV CTR', 6),
#  ('CHURCHS CHICKEN 701', 6),
#  ('PER EHSII RANDY MARTINEZ FA OOB 7/1/14 SOMEBODY LOVES ME', 6),
#  ('SAHARA MIDDLE EASTERN EATERY', 6),
#  ('PIZZA CASTLE', 6),
#  ('PER EHSII MICHAEL PITTMAN FA OOB 6/25/14 FURRS FRESH BUFFET', 6),
#  ('MCALISTERS DELI', 6),
#  ('OOB HALLENBRICK BREWERY LLC', 6),
#  ('THE FRUIT BASKET 4', 6),
#  ('DOC N EDDYS', 6),
#  ('OOB LA MICHUACANA USA', 6),
#  ('PER EHSII ROSANNA TRUJILLO FA OOB 02/11/14 MCDONALDS 220', 6),
#  ('LAMS CHINESE RESTAURANT 1', 6),
#  ('RESIDENCE INN BY MARRIOTT', 6),
#  ('OOB PHO SAIGON', 6),
#  ('WALGREENS 03997', 6),
#  ('OOB CHINA CASA', 6),
#  ('OOB PER WRITTEN REQUEST 10/04/12MES AMIS TEA HOUSE', 6),
#  ('COA - FAMILY & COMMUNITY SVCS', 6),
#  ('OOB SUBWAY NO 26812', 6),
#  ('7 ELEVEN 717', 6),
#  ('FAMILY DOLLAR STORES OF NM 5506', 6),
#  ('OOB QUE HUONG VIETNAMESE REST', 6),
#  ('LOWELL CHILD DEVELOPMENT CENTER', 6),
#  ('OUEIS GAS', 6),
#  ('OOB WORKING CLASS KITCHEN', 6),
#  ('OOB INDULGENCE CAFE & CATERING INC', 6),
#  ('LONGFELLOW ELEMENTARY', 6),
#  ('OOB CIRCLE K 6293', 6),
#  ('7 ELEVEN 715', 6),
#  ('DEL NORTE BAPTIST CHURCH', 6),
#  ('PER EHSII ZAHRA KANJI FA OOB 10/01/13 EL NORTENO LTD CO', 6),
#  ('OOB PER WRITTEN REQUEST EL MICHOACANO RESTAURANT', 6),
#  ('HURRICANES INC', 6),
#  ('SAFFRON TIGER', 6),
#  ('BAYMONT INN AND SUITES', 6),
#  ('OOB TOOL BOX EATS', 6),
#  ('DOWNTOWN LIQUOR AND FOOD MART LLC', 6),
#  ('OOB SIERRA ALTERNATIVE HIGH SCHOOL', 6),
#  ('OOB C & E REDI MART', 6),
#  ('MCDONALDS 3907', 6),
#  ('KIRTLAND ELEMENTARY', 6),
#  ('FAMILY DOLLAR STORES OF NM 2827', 6),
#  ('OOB CIRCLE K 8745', 6),
#  ('OOB 9/18/14 RICE GARDEN', 6),
#  ('TORTILLERIA LA POBLANA', 6),
#  ('TOMASITA ELEMENTARY', 6),
#  ('OOB PER WRITTEN REQUEST COPPER EXPRESS NORTH', 6),
#  ('OOB VILLAGE INN 110010', 6),
#  ('EL VAN VAN', 6),
#  ('CANTEEN OF NM @ HOPE CHRISTIAN MS', 6),
#  ('OOB08/27/13CARLS JR', 6),
#  ('OOB 7/29/13LE CAFE MICHE BISTRO', 6),
#  ('7 ELEVEN 709', 6),
#  ('OOB COMFORT FOODS', 6),
#  ('OOB ASIAN CAFE LLC', 6),
#  ('SPECIAL TOUCH CATERING LC', 6),
#  ('ROBERT F KENNEDY CHARTER SCHOOL', 6),
#  ('ELDORADO HIGH SCHOOL', 6),
#  ('LOS CUATES NORTH', 6),
#  ('LA PETITE DAY CARE', 6),
#  ('HUSKY STORE THE', 6),
#  ('DOLLAR TREE 2967', 6),
#  ('OOB HOLY GHOST SCHOOL', 6),
#  ('OOB PER WRITTEN REQUEST 12/23/13 THIN AIR PRODUCTIONS', 6),
#  ('PIT STOP III', 6),
#  ('PER EHSII CECELIA M GARCIA FA OOB 01/31/14 CORNER STORE 1212', 6),
#  ('ANNAPURNA CHAI HOUSE', 6),
#  ('PER TREASURY FA OOB DAYS INN', 6),
#  ('BURGER KING 17161', 6),
#  ('HELEN CORDERO ELEMENTARY', 6),
#  ('DECA MUSTANG ROUNDUP', 6),
#  ('KINDER CARE LEARN CTR 324', 6),
#  ('SHARK REEF RESTAURANT', 6),
#  ('OOB DAWN SANCHEZ CREATIONS LLC', 6),
#  ('IL VICINO HEIGHTS', 6),
#  ('LA VIDA LLENA', 6),
#  ('LA RESOLANA LEADERSHIP ACADEMY', 6),
#  ('OOB JBS RESTAURANT', 6),
#  ('MCDONALDS 30148', 6),
#  ('SUBWAY @ PRESBYTERIAN', 6),
#  ('HOFFMANTOWN BAPTIST CHURCH', 6),
#  ('OOB STARBUCKS COFFEE #5429', 6),
#  ('PER EHSII JAY COUSINS FA OOB 3/1/14 PREMIER GAS NO 2', 6),
#  ('BASILS HOME COOKING', 6),
#  ('IMBIBE', 6),
#  ('ST JOHNS HEALTHCARE & REHAB', 6),
#  ('OOB THE CREPE CAFE', 6),
#  ('JIMMYS CAFE', 6),
#  ('SAN PEDRO MIDDLE EAST GROCERY AND R', 6),
#  ('OOB OOB BAGELS AND BEYOND LLC', 6),
#  ('A-1 ORIENTAL MARKET', 6),
#  ('PIZZA HUT 012973', 6),
#  ('OOB DOG GONE GOOD', 6),
#  ('ROSE GARDEN CHINESE RESTAURANT LLC', 6),
#  ('SANDWICH CO.  THE', 6),
#  ('OOB CIRCLE K 6145', 6),
#  ('SMG LLC', 6),
#  ('GOVERNOR BENT ELEMENTARY PTA', 6),
#  ('DUNKIN/BASKIN ROBBIN', 6),
#  ('ARROYO DEL OSO ELEMENTARY', 6),
#  ('OOB A AND M CHEVRON', 6),
#  ('BUDAI GOURMET CHINESE', 6),
#  ('JCS NEW YORK PIZZA DEPT', 6),
#  ('TRI-H CONVENIENCE STORE', 6),
#  ('YDI HIGHLAND HIGH SCHOOL', 6),
#  ('HUA CHANG CHINESE RESTAURANT', 6),
#  ('MAX DRIVE NUTRITION', 6),
#  ('ALB HEIGHTS HEALTHCARE & REHAB', 6),
#  ('STARBUCKS COFFEE 5411', 6),
#  ('OOB SUNSET VIEW CHILDCARE', 6),
#  ('DOG HOUSE', 6),
#  ('TACO BELL 16602', 6),
#  ('CESARS MEXICAN & GREEK', 6),
#  ('OOB OUT TO LUNCH COFFEE AND SANDWICH BA', 6),
#  ('MARK TWAIN ELEMENTARY', 6),
#  ('OOB OH HEAVENS CHEESECAKES LLC', 6),
#  ('RIVERPOINT SWIM & RACQUET CLUB', 6),
#  ('FAMILY DOLLAR STORES NM 6416', 6),
#  ('PANDA EXPRESS  1158', 6),
#  ('PAPA FRANKS', 6),
#  ('OOB COLD STONE CREAMERY 259', 6),
#  ('PER EHSII ZAHRA KANJI FA OOB 4/1/14 MR SUSHI', 6),
#  ('AMADEOS PIZZA & SUBS', 6),
#  ('OOB CIRCLE K 8551', 6),
#  ('AFC SUSHI AT SMITHS 496', 6),
#  ('ANNIES SOUP KITCHEN', 6),
#  ('GLORIAS NM BURRITOS AND MORE', 6),
#  ('OOB KAIYOTE MART', 6),
#  ('OOB ROUTE 66 MICROBREWERY', 6),
#  ('DEL NORTE CONFERENCE CENTER', 6),
#  ('OOB MARISCOS EL KORA', 6),
#  ('OOB NOTHING BUT NOODLES #1', 6),
#  ('TOMASITA CHILD DEVELOPMENT CENTER', 6),
#  ('FASTINOS', 6),
#  ('OOB CIRCLE K 1777', 6),
#  ('ORCHID THAI CUISINE', 6),
#  ("THE CHILDREN'S CENTER", 6),
#  ('ABC CAKE SHOP INC', 6),
#  ('OOB LA QUICHE PARISIENNE BISTRO', 6),
#  ('WALGREENS 12407', 6),
#  ('LYNDON B JOHNSON MIDDLE SCHOOL', 6),
#  ('GRIFFS OF ALBUQUERQUE', 6),
#  ('MARIE HUGHES ELEMENTARY', 6),
#  ('FIRST UNITED METHODIST', 6),
#  ('WATCH  SPORTS LOUNGE AND GRILL', 6),
#  ('PIZZA HUT 012949', 6),
#  ('CORNUCOPIA ADULT DAY CARE SRV', 6),
#  ('WOLFES BAGELS', 6),
#  ('COMET CAFE', 6),
#  ('MCDONALDS 30903', 6),
#  ('ITSA ITALIAN ICE', 6),
#  ('OOB PER CHANGE IN OWNERSHIP BRASSERIE LA PROVENCE', 6),
#  ('IL VICINO INTERNATIONAL LLC /DBA IL VICINO WESTSIDE', 6),
#  ('OUR LADY OF FATIMA SCHOOL', 6),
#  ('RIO VISTA CHILDCARE', 6),
#  ('OOB FOUR HILLS CHEVRON REDIMART', 6),
#  ('TWISTERS 22', 6),
#  ('OOB EDIBLE ARRANGEMENTS', 6),
#  ('DOLLAR TREE 2689', 6),
#  ('THAI CUISINE RESTAURANT', 6),
#  ('PAPA JOHNS PIZZA 1342', 6),
#  ('OOB LIU CHINESE FAST FOOD', 6),
#  ('RAMADA LIMITED', 6),
#  ('LOS ALTOS GOLF CONCESS INC', 6),
#  ...]

# %% [markdown]
# It appear that one facility in particular has been inspected much more than any other. Let's take a closer look.

# %%
# %%sql
# SELECT "INSPECTION_DESC", COUNT(*) FROM inspections
# WHERE "FACILITY_NAME" = 'SMITHS FOOD AND DRUG CENTERS INC'
# GROUP BY "INSPECTION_DESC";
# Out:
# 4 rows affected.
# [('ROUTINE FOOD INSPECTION', 130),
#  ('EMERGENCY RESPONSE', 15),
#  ('PHONE CALL', 7),
#  ('ADDITIONAL SERVICE PROVIDED', 2)]

# %% [markdown]
# It appears that they have had more "routine" inspections than any other restaurant has had total inspections... Strange. Maybe the restaurant is on an inspector's naughty list

# %% [markdown]
# Are there more inspections that take place in certain zip codes?

# %%
# %%sql
# SELECT "ZIP", COUNT(*) AS num_inspections FROM inspections
# GROUP BY "ZIP"
# ORDER BY COUNT(*) DESC;
# Out:
# 48 rows affected.
# [('87110', 1996),
#  ('87108', 1976),
#  ('87102', 1601),
#  ('87106', 1568),
#  ('87109', 1552),
#  ('87107', 1186),
#  ('87112', 1151),
#  ('87114', 1053),
#  ('87123', 1017),
#  ('87111', 1008),
#  ('87121', 879),
#  ('87120', 789),
#  ('87105', 533),
#  ('87104', 527),
#  ('87113', 326),
#  ('87122', 112),
#  ('87103', 35),
#  ('87119', 34),
#  ('871145010', 22),
#  ('87124', 20),
#  ('871221303', 20),
#  ('87101', 15),
#  ('871131512', 13),
#  ('87117', 10),
#  ('871023114', 9),
#  ('87116', 7),
#  ('871113971', 7),
#  ('871222949', 7),
#  ('871104973', 6),
#  ('871087121', 6),
#  ('87111-3146', 6),
#  ('87158', 6),
#  ('871101922', 6),
#  ('87187', 5),
#  ('87192', 5),
#  ('871104546', 5),
#  ('871085004', 4),
#  ('871147010', 4),
#  ('871147005', 4),
#  ('87017', 3),
#  ('871084815', 3),
#  ('871124722', 3),
#  ('871094620', 3),
#  ('871118200', 3),
#  ('871084174', 3),
#  ('87100', 3),
#  ('871112648', 3),
#  ('87197', 2)]

# %% [markdown]
# The data is not stored consistently... Sometimes the ZIP is stored as five numbers sometimes it is more detailed. Let's change the query

# %%
# %%sql
# SELECT DISTINCT substring("ZIP",1,5) AS "ZIP", COUNT(*) FROM inspections
# GROUP BY substring("ZIP",1,5)
# ORDER BY COUNT(*) DESC;
# Out:
# 28 rows affected.
# [('87110', 2013),
#  ('87108', 1992),
#  ('87102', 1610),
#  ('87106', 1568),
#  ('87109', 1555),
#  ('87107', 1186),
#  ('87112', 1154),
#  ('87114', 1083),
#  ('87111', 1027),
#  ('87123', 1017),
#  ('87121', 879),
#  ('87120', 789),
#  ('87105', 533),
#  ('87104', 527),
#  ('87113', 339),
#  ('87122', 139),
#  ('87103', 35),
#  ('87119', 34),
#  ('87124', 20),
#  ('87101', 15),
#  ('87117', 10),
#  ('87116', 7),
#  ('87158', 6),
#  ('87187', 5),
#  ('87192', 5),
#  ('87017', 3),
#  ('87100', 3),
#  ('87197', 2)]

# %% [markdown]
# As we can see some zip codes are seeing a lot more activity than others

# %% [markdown]
# ## Bonus (10 points)
#
# We have seen a few simple techniques for normalizing data in class.  Choose a column or set of columns that might be redundant and normalize them out to another table:
#
# * Identify the columns to normalize in the source data table
# * Create one or more new tables to hold the normalized records
# * Extract data into the new tables
# * Re-insert the new foreign key references from the new table into the source table

# %% [markdown]
# I will normalize the columns PROGRAM_CATEGORY and PROGRAM_CATEGORY_DESCRIPTION. To do so, I first create the table to hold the normalized records

# %%
# %%sql
# DROP TABLE IF EXISTS programs;
# CREATE TABLE programs (
# id int primary key,
# description varchar(64)
# );
# Out:
# Done.
# Done.
# []

# %% [markdown]
# Then I insert all the possible program codes from the inspections table

# %%
# %%sql
# INSERT INTO programs (id)
# SELECT DISTINCT CAST("PROGRAM_CATEGORY" as int) FROM inspections;
# Out:
# 25 rows affected.
# []

# %% [markdown]
# I then update the value of the program description to match the description in the inspections table

# %%
# %%sql
# UPDATE programs as p
# SET description = i."PROGRAM_CATEGORY_DESCRIPTION"
# FROM inspections as i
# WHERE id = CAST(i."PROGRAM_CATEGORY" as int)
# Out:
# 25 rows affected.
# []

# %% [markdown]
# Let's take a look at our new table:

# %%
# %%sql
# SELECT * FROM programs
# Out:
# 25 rows affected.
# [(402, 'Childcare'),
#  (403, 'Bakery'),
#  (404, 'Institutional Kitchen'),
#  (405, 'Food Processor'),
#  (406, 'Food Service Establishment'),
#  (407, 'Limited Menu'),
#  (408, 'School'),
#  (409, 'Non School'),
#  (410, 'NOT FOR PROFIT KITCHEN PERMIT'),
#  (411, None),
#  (501, 'Bar'),
#  (601, 'Retail -Grocery'),
#  (602, 'Meat Market'),
#  (603, 'Warehouse'),
#  (604, 'Seasonal Venue -Fixed Location'),
#  (605, 'Seasonal Location -Food Service Permit'),
#  (606, 'Retail - Prepackage Only'),
#  (607, 'Retail - Self Service & Prepackage Foods'),
#  (608, 'Retail - Deli'),
#  (609, 'Retail - Meat/Seafood'),
#  (610, 'Retail - Specialty Food Permit'),
#  (1000, 'Frozen Food Truck'),
#  (1001, 'Mobile Pre-Packaged'),
#  (1002, 'Mobile Food Unit'),
#  (1003, 'Food/Drink Vending - Up to 15 Units')]

# %% [markdown]
# For further queries, it is probably good to change the data type of program description in table inspections to match the data type used in our new normalized table

# %%
# %%sql
# ALTER TABLE inspections
# ALTER COLUMN "PROGRAM_CATEGORY" SET DATA TYPE int USING "PROGRAM_CATEGORY"::integer
# Out:
# Done.
# []

# %% [markdown]
# Re-insert foreign key references to the original inspections table

# %%
# %%sql
# ALTER TABLE inspections
# ADD FOREIGN KEY ("PROGRAM_CATEGORY") REFERENCES programs (id)
# Out:
# Done.
# []
